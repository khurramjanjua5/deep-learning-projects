# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler
import numpy as np

# Load the dataset
data = pd.read_csv("laptops.csv")

# Drop unnecessary columns
data.drop(columns=["Laptop", "Status"], inplace=True)

# Perform one-hot encoding for categorical variables
data = pd.get_dummies(data, columns=["Brand", "Model", "CPU", "Storage type", "GPU"], drop_first=True)

# Convert 'Touch' column to numerical representation
data['Touch'] = data['Touch'].map({'Yes': 1, 'No': 0})

# Handle missing values
data.fillna(data.mean(), inplace=True)

# Separate features and target variable
X = data.drop(columns=["Final Price"])
y = data["Final Price"]

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the neural network model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

# Define a learning rate scheduler
def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch != 0:
        return lr * 0.9
    else:
        return lr

# Compile the model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, callbacks=[LearningRateScheduler(lr_scheduler)])

# Evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# Calculate R-squared score
y_mean = np.mean(y_test)
ss_total = np.sum((y_test - y_mean) ** 2)
ss_residual = np.sum((y_test - y_pred.flatten()) ** 2)
r_squared = 1 - (ss_residual / ss_total)
print("R-squared (R2) score:", r_squared)
# Out:
# Epoch 1/100
# D:\anaconda\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2468767.0000 - val_loss: 2197485.7500 - learning_rate: 0.0010
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2327173.2500 - val_loss: 1905608.6250 - learning_rate: 0.0010
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1952493.7500 - val_loss: 1182144.1250 - learning_rate: 0.0010
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1061932.2500 - val_loss: 435060.5938 - learning_rate: 0.0010
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 347248.6875 - val_loss: 200194.5000 - learning_rate: 0.0010
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 214648.4375 - val_loss: 154055.4375 - learning_rate: 0.0010
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 175169.2500 - val_loss: 137405.1094 - learning_rate: 0.0010
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 186256.8906 - val_loss: 128649.2422 - learning_rate: 0.0010
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 152819.2812 - val_loss: 125229.5547 - learning_rate: 0.0010
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 152904.8906 - val_loss: 118728.3516 - learning_rate: 0.0010
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 132678.3594 - val_loss: 117082.3203 - learning_rate: 9.0000e-04
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 141166.2344 - val_loss: 114898.9766 - learning_rate: 9.0000e-04
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 156217.4531 - val_loss: 112396.8359 - learning_rate: 9.0000e-04
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 136545.9375 - val_loss: 110577.0000 - learning_rate: 9.0000e-04
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133318.7812 - val_loss: 110907.6016 - learning_rate: 9.0000e-04
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 135689.0781 - val_loss: 111832.6250 - learning_rate: 9.0000e-04
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131563.3906 - val_loss: 110456.8438 - learning_rate: 9.0000e-04
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 128398.9297 - val_loss: 110308.2188 - learning_rate: 9.0000e-04
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 116576.3125 - val_loss: 108574.2812 - learning_rate: 9.0000e-04
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 116092.9609 - val_loss: 108226.9766 - learning_rate: 9.0000e-04
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 107240.0625 - val_loss: 110050.1016 - learning_rate: 8.1000e-04
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 114692.3594 - val_loss: 109117.6641 - learning_rate: 8.1000e-04
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 118164.0859 - val_loss: 106889.9297 - learning_rate: 8.1000e-04
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 134479.5469 - val_loss: 107019.4141 - learning_rate: 8.1000e-04
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 114186.5547 - val_loss: 107506.7266 - learning_rate: 8.1000e-04
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 109782.7422 - val_loss: 104182.6250 - learning_rate: 8.1000e-04
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 114382.4062 - val_loss: 104926.1875 - learning_rate: 8.1000e-04
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110415.8203 - val_loss: 104288.4609 - learning_rate: 8.1000e-04
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 112121.1250 - val_loss: 104829.0391 - learning_rate: 8.1000e-04
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 119606.5859 - val_loss: 104753.2500 - learning_rate: 8.1000e-04
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 103590.6484 - val_loss: 104802.4609 - learning_rate: 7.2900e-04
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 115936.5625 - val_loss: 103593.1797 - learning_rate: 7.2900e-04
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112037.0312 - val_loss: 104073.6016 - learning_rate: 7.2900e-04
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 114278.8438 - val_loss: 103330.7422 - learning_rate: 7.2900e-04
# Epoch 35/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 114292.1016 - val_loss: 104937.8125 - learning_rate: 7.2900e-04
# Epoch 36/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 108478.3516 - val_loss: 105784.7500 - learning_rate: 7.2900e-04
# Epoch 37/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 112178.7422 - val_loss: 103628.1016 - learning_rate: 7.2900e-04
# Epoch 38/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 132531.8281 - val_loss: 104943.0547 - learning_rate: 7.2900e-04
# Epoch 39/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 100619.9766 - val_loss: 104701.2578 - learning_rate: 7.2900e-04
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126497.3359 - val_loss: 105732.6953 - learning_rate: 7.2900e-04
# Epoch 41/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 114871.4297 - val_loss: 105020.7109 - learning_rate: 6.5610e-04
# Epoch 42/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 113127.8438 - val_loss: 102281.7812 - learning_rate: 6.5610e-04
# Epoch 43/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 105573.4062 - val_loss: 101201.5234 - learning_rate: 6.5610e-04
# Epoch 44/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110397.3828 - val_loss: 100859.8125 - learning_rate: 6.5610e-04
# Epoch 45/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110688.6016 - val_loss: 104902.8359 - learning_rate: 6.5610e-04
# Epoch 46/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110373.6875 - val_loss: 102849.4297 - learning_rate: 6.5610e-04
# Epoch 47/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 105241.4688 - val_loss: 102579.0078 - learning_rate: 6.5610e-04
# Epoch 48/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 113696.1797 - val_loss: 100317.8125 - learning_rate: 6.5610e-04
# Epoch 49/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 109525.7578 - val_loss: 99541.6016 - learning_rate: 6.5610e-04
# Epoch 50/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 118533.3125 - val_loss: 101707.5312 - learning_rate: 6.5610e-04
# Epoch 51/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 123552.2031 - val_loss: 103010.2266 - learning_rate: 5.9049e-04
# Epoch 52/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 106177.1094 - val_loss: 100155.1562 - learning_rate: 5.9049e-04
# Epoch 53/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 107623.6719 - val_loss: 102059.6562 - learning_rate: 5.9049e-04
# Epoch 54/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 108008.6797 - val_loss: 100711.7891 - learning_rate: 5.9049e-04
# Epoch 55/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 112692.3672 - val_loss: 100133.6797 - learning_rate: 5.9049e-04
# Epoch 56/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 108964.5234 - val_loss: 99769.5547 - learning_rate: 5.9049e-04
# Epoch 57/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 115375.7500 - val_loss: 99743.5547 - learning_rate: 5.9049e-04
# Epoch 58/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 117205.3750 - val_loss: 101301.9062 - learning_rate: 5.9049e-04
# Epoch 59/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 109011.0547 - val_loss: 100206.5000 - learning_rate: 5.9049e-04
# Epoch 60/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104758.1484 - val_loss: 98056.7578 - learning_rate: 5.9049e-04
# Epoch 61/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 111118.5781 - val_loss: 98288.9375 - learning_rate: 5.3144e-04
# Epoch 62/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 100070.1094 - val_loss: 100049.0547 - learning_rate: 5.3144e-04
# Epoch 63/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 120728.6016 - val_loss: 99112.7812 - learning_rate: 5.3144e-04
# Epoch 64/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 107811.9688 - val_loss: 97894.5547 - learning_rate: 5.3144e-04
# Epoch 65/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 101130.1094 - val_loss: 97462.2812 - learning_rate: 5.3144e-04
# Epoch 66/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 119912.1719 - val_loss: 98656.0547 - learning_rate: 5.3144e-04
# Epoch 67/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 115418.6562 - val_loss: 96667.5078 - learning_rate: 5.3144e-04
# Epoch 68/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 113603.8828 - val_loss: 97982.4062 - learning_rate: 5.3144e-04
# Epoch 69/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98196.3047 - val_loss: 98066.9453 - learning_rate: 5.3144e-04
# Epoch 70/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95434.8750 - val_loss: 98154.6484 - learning_rate: 5.3144e-04
# Epoch 71/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104782.3672 - val_loss: 98349.0625 - learning_rate: 4.7830e-04
# Epoch 72/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 123408.6484 - val_loss: 98786.2266 - learning_rate: 4.7830e-04
# Epoch 73/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 105667.7734 - val_loss: 97603.9062 - learning_rate: 4.7830e-04
# Epoch 74/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 102324.8594 - val_loss: 98720.3359 - learning_rate: 4.7830e-04
# Epoch 75/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 113102.6797 - val_loss: 97445.0859 - learning_rate: 4.7830e-04
# Epoch 76/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 108986.5078 - val_loss: 97268.2500 - learning_rate: 4.7830e-04
# Epoch 77/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95075.7500 - val_loss: 97265.7891 - learning_rate: 4.7830e-04
# Epoch 78/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110940.8516 - val_loss: 98269.9375 - learning_rate: 4.7830e-04
# Epoch 79/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 108548.8359 - val_loss: 97902.0312 - learning_rate: 4.7830e-04
# Epoch 80/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 107855.7344 - val_loss: 97167.4297 - learning_rate: 4.7830e-04
# Epoch 81/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 103683.1172 - val_loss: 96784.2891 - learning_rate: 4.3047e-04
# Epoch 82/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 118561.7500 - val_loss: 95745.3750 - learning_rate: 4.3047e-04
# Epoch 83/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 122828.1328 - val_loss: 95805.9766 - learning_rate: 4.3047e-04
# Epoch 84/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 118707.2656 - val_loss: 95132.0078 - learning_rate: 4.3047e-04
# Epoch 85/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89967.2344 - val_loss: 97030.3438 - learning_rate: 4.3047e-04
# Epoch 86/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 108004.5234 - val_loss: 95387.2734 - learning_rate: 4.3047e-04
# Epoch 87/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 102988.8672 - val_loss: 94822.9062 - learning_rate: 4.3047e-04
# Epoch 88/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 118867.1797 - val_loss: 93223.5547 - learning_rate: 4.3047e-04
# Epoch 89/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 111586.5859 - val_loss: 92134.0859 - learning_rate: 4.3047e-04
# Epoch 90/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 109588.5156 - val_loss: 93643.8516 - learning_rate: 4.3047e-04
# Epoch 91/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104652.0703 - val_loss: 93434.7812 - learning_rate: 3.8742e-04
# Epoch 92/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 102793.3438 - val_loss: 93684.6328 - learning_rate: 3.8742e-04
# Epoch 93/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104642.6172 - val_loss: 94228.9297 - learning_rate: 3.8742e-04
# Epoch 94/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 108453.0469 - val_loss: 95547.2578 - learning_rate: 3.8742e-04
# Epoch 95/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89783.2266 - val_loss: 94162.5312 - learning_rate: 3.8742e-04
# Epoch 96/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 87461.5938 - val_loss: 93370.7812 - learning_rate: 3.8742e-04
# Epoch 97/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 87620.8281 - val_loss: 92928.3516 - learning_rate: 3.8742e-04
# Epoch 98/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 92463.4141 - val_loss: 93305.3203 - learning_rate: 3.8742e-04
# Epoch 99/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 105935.9922 - val_loss: 92739.6172 - learning_rate: 3.8742e-04
# Epoch 100/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 111437.6094 - val_loss: 93053.6328 - learning_rate: 3.8742e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Mean Squared Error (MSE): 223675.6955966826
# R-squared (R2) score: 0.7574351319766061
